# %%
from pandas_datareader import data,wb

# %%
dict = data.get_data_yahoo('MSFT')

# %%
from pandas import DataFrame

# %%
dict['prices']
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2009-12-31  30.990000  30.480000  30.980000  30.480000   31929700.0  24.651169
# 2010-01-04  31.100000  30.590000  30.620001  30.950001   38409100.0  25.031296
# 2010-01-05  31.100000  30.639999  30.850000  30.959999   49749600.0  25.039383
# 2010-01-06  31.080000  30.520000  30.879999  30.770000   58182400.0  24.885712
# 2010-01-07  30.700001  30.190001  30.629999  30.450001   50559700.0  24.626907
# 2010-01-08  30.879999  30.240000  30.280001  30.660000   51197400.0  24.796747
# 2010-01-11  30.760000  30.120001  30.709999  30.270000   68754700.0  24.481335
# 2010-01-12  30.400000  29.910000  30.150000  30.070000   65912100.0  24.319574
# 2010-01-13  30.520000  30.010000  30.260000  30.350000   51863500.0  24.546034
# 2010-01-14  31.100000  30.260000  30.309999  30.959999   63228100.0  25.039383
# 2010-01-15  31.240000  30.709999  31.080000  30.860001   79913200.0  24.958502
# ...

# %%
frame = DataFrame(dict['prices'])

# %%
frame
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2009-12-31  30.990000  30.480000  30.980000  30.480000   31929700.0  24.651169
# 2010-01-04  31.100000  30.590000  30.620001  30.950001   38409100.0  25.031296
# 2010-01-05  31.100000  30.639999  30.850000  30.959999   49749600.0  25.039383
# 2010-01-06  31.080000  30.520000  30.879999  30.770000   58182400.0  24.885712
# 2010-01-07  30.700001  30.190001  30.629999  30.450001   50559700.0  24.626907
# 2010-01-08  30.879999  30.240000  30.280001  30.660000   51197400.0  24.796747
# 2010-01-11  30.760000  30.120001  30.709999  30.270000   68754700.0  24.481335
# 2010-01-12  30.400000  29.910000  30.150000  30.070000   65912100.0  24.319574
# 2010-01-13  30.520000  30.010000  30.260000  30.350000   51863500.0  24.546034
# 2010-01-14  31.100000  30.260000  30.309999  30.959999   63228100.0  25.039383
# 2010-01-15  31.240000  30.709999  31.080000  30.860001   79913200.0  24.958502
# ...
